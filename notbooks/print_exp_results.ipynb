# %%
import pandas as pd
import os


results_dir = \
"/home/liranc6/W25/adversarial-attacks-on-deep-learning/project/Unlearn-Simple/comprehensive_results/subset_size-1000/2025-09-14_09-11"
# "/home/liranc6/W25/adversarial-attacks-on-deep-learning/project/comprehensive_results/subset_size-1000/2025-09-13_21-56"
    
# exp_time = '2025-09-13_21-53'
# SUBSET_SIZE = 1000
# results_dir = os.path.join(results_dir, f"subset_size-{SUBSET_SIZE}", exp_time)

# Table 2: Aggregate Comparison
table2_path = os.path.join(results_dir, "table2_aggregate_comparison.csv")
if os.path.exists(table2_path):
    table2 = pd.read_csv(table2_path)
    print("\n" + "="*80)
    print("TABLE 2: AGGREGATE COMPARISON OF UNLEARNING EVALUATION METRICS")
    print("="*80)
    print(table2.to_string(index=False))
else:
    print(f"❌ Table 2 not found at {table2_path}")

# Table 3: Model Family Comparison
table3_path = os.path.join(results_dir, "table3_model_family_comparison.csv")
if os.path.exists(table3_path):
    table3 = pd.read_csv(table3_path)
    print("\n" + "="*80)
    print("TABLE 3: AGGREGATE COMPARISON ACROSS MODEL FAMILIES")
    print("="*80)
    print(table3.head(20).to_string(index=False))  # Show first 20 rows
else:
    print(f"❌ Table 3 not found at {table3_path}")

# Table 4: Detailed Individual Results
table4_path = os.path.join(results_dir, "table4_detailed_results.csv")
if os.path.exists(table4_path):
    table4 = pd.read_csv(table4_path)
    print("\n" + "="*80)
    print("TABLE 4: DETAILED SCORES FOR INDIVIDUAL MODELS (First 10)")
    print("="*80)
    print(table4[['Model', 'Benchmark', 'Method', 'Classifier', 'AUC', 'Accuracy', 'F1']].head(10).to_string(index=False))
else:
    print(f"❌ Table 4 not found at {table4_path}")

# All detailed results (optional)
detailed_path = os.path.join(results_dir, "all_detailed_results.csv")
if os.path.exists(detailed_path):
    detailed = pd.read_csv(detailed_path)
    print("\nFirst 5 rows of all detailed results:")
    print(detailed)
else:
    print(f"❌ Detailed results not found at {detailed_path}")
# Out:
# ...
# TABLE 2: AGGREGATE COMPARISON OF UNLEARNING EVALUATION METRICS
# ...
#                 Method  Retained_vs_Forgotten_AUC  Forgotten_vs_Holdout_AUC  Overall
#         QA-based score                      0.620                     0.580    0.600
#       Zlib Compression                      0.650                     0.610    0.630
#               MIN-K%++                      0.680                     0.640    0.660
#             ROUGE-L F1                      0.600                     0.550    0.570
# EPP-UE - LogReg (ours)                      0.900                     0.875    0.806
#   EPP-UE - Tree (ours)                      0.888                     0.831    0.644
#
# ...
# TABLE 3: AGGREGATE COMPARISON ACROSS MODEL FAMILIES
# ...
# Model_Family Method Classifier   AUC  Accuracy    F1  Retain_vs_All  Forget_vs_All
#   LLaMA-2-7B SimNPO     LogReg 0.785      0.50 0.480          0.875          0.844
#   LLaMA-2-7B SimNPO       Tree 0.583      0.45 0.440          0.859          0.789
# ...
