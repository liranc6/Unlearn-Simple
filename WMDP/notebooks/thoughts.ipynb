# %% [markdown]
# The WMDP dataset is a Q&A dataset where the questions are multi-choice.
# In order to use it I need to think how to modify it to my permutations generation. I think I can permute only the question, yet how can I justify it to my black box test, can I say that I have my answers?

# %% [markdown]
# I decided to run it as it was finetuned, and change only the question. As I did in the TOFU dataset.

# %% [markdown]
# It makes me think I can state that my method is very versatile, and can work on any task and dataset, as long as the attacker can get the loss.

# %% [markdown]
# If I will use the models from https://huggingface.co/LLM-GAT/collections published for the paper https://arxiv.org/abs/2502.05209,
# I can also examine the forgetting process.

# %% [markdown]
# # Insight!
# 1. the attack works also with a general tokenizer for noise insertion, but when running the model, we must use the matching tokenizer (not new insight that they must match).
